# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
path = "/content/drive/MyDrive/code/WZ"
os.chdir(path)
print(os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import os
#       2 path = "/content/drive/MyDrive/code/WZ"
# ----> 3 os.chdir(path)
#       4 print(os.getcwd())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/code/WZ'

# %%
import importlib
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import copy
from collections import deque


sizef = 8

# %%
class Gomoku:
    def __init__(self, size=sizef, black_strategy=None, white_strategy=None):
        self.size = size  # 棋盘大小
        self.board = [['.' for _ in range(size)] for _ in range(size)]  # 初始化棋盘
        self.current_player = 'X'  # 当前玩家 ('X' or 'O')
        self.black_strategy = black_strategy  # 黑棋策略函数
        self.white_strategy = white_strategy  # 白棋策略函数

    def display_board(self):
        """打印棋盘"""
        print("   " + " ".join(f"{i:2}" for i in range(self.size)))
        for i, row in enumerate(self.board):
            print(f"{i:2} " + " ".join(row))

    def is_valid_move(self, x, y):
        """检查落子是否合法"""
        return 0 <= x < self.size and 0 <= y < self.size and self.board[x][y] == '.'

    def make_move(self, x, y):
        """下棋"""
        if self.is_valid_move(x, y):
            self.board[x][y] = self.current_player
            return True
        else:
            print(f"Invalid move by player {self.current_player} at ({x}, {y}).")
            return False

    def check_winner(self, x, y):
        """检查当前玩家是否获胜"""
        directions = [(1, 0), (0, 1), (1, 1), (1, -1)]  # 四个方向：水平、垂直、正斜线、反斜线
        for dx, dy in directions:
            count = 1
            # 检查正方向
            for step in range(1, 5):
                nx, ny = x + step * dx, y + step * dy
                if 0 <= nx < self.size and 0 <= ny < self.size and self.board[nx][ny] == self.current_player:
                    count += 1
                else:
                    break
            # 检查反方向
            for step in range(1, 5):
                nx, ny = x - step * dx, y - step * dy
                if 0 <= nx < self.size and 0 <= ny < self.size and self.board[nx][ny] == self.current_player:
                    count += 1
                else:
                    break
            if count >= 5:  # 连续五子
                return True
        return False

    def switch_player(self):
        """切换玩家"""
        self.current_player = 'O' if self.current_player == 'X' else 'X'

    def play(self):
        """游戏主循环"""
        print("Starting Gomoku!")
        self.display_board()

        # 检查是否有 GPU 可用
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        print(f"Running on device: {device}")

        while True:
            if self.current_player == 'X':
                if self.black_strategy:
                    # 将策略函数运行在指定设备上
                    move = self.black_strategy(self.board, 'X', device=device)
                else:
                    move = self.get_human_move()
            else:
                if self.white_strategy:
                    # 将策略函数运行在指定设备上
                    move = self.white_strategy(self.board, 'O', device=device)
                else:
                    move = self.get_human_move()

            if not move or len(move) != 2:
                print(f"Invalid move returned by player {self.current_player}.")
                break

            x, y = move
            if self.make_move(x, y):
                print(f"Player {self.current_player} places at ({x}, {y})")
                self.display_board()
                if self.check_winner(x, y):
                    print(f"Player {self.current_player} wins!")
                    break
                self.switch_player()
            else:
                print("Game Over due to invalid move.")
                break

        print("Game Over!")

    def get_human_move(self):
        """获取玩家的落子"""
        while True:
            try:
                move = input(f"Player {self.current_player}, enter your move (row col): ").strip()
                x, y = map(int, move.split())
                if self.is_valid_move(x, y):
                    return x, y
                else:
                    print("Invalid move. Try again.")
            except ValueError:
                print("Invalid input. Please enter row and column numbers separated by a space.")


def load_strategy(file_name):
    """从本地文件加载策略"""
    if not os.path.exists(file_name):
        raise FileNotFoundError(f"Strategy file {file_name} not found.")

    module_name = os.path.splitext(os.path.basename(file_name))[0]
    spec = importlib.util.spec_from_file_location(module_name, file_name)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module.play  # 假设策略文件中定义了一个 play 函数



def print_strategy_files(directory):
    try:
        for root, dirs, files in os.walk(directory):
            for file in files:
                if file.endswith("strategy.py"):
                    print(file)
    except Exception as e:
        print(f"Invaid: {e}")

# %%
print("Welcome to Gomoku!")
print("Choose game mode:")
print("1. Human vs AI")
print("2. AI vs AI")
mode = input("Enter 1 or 2: ").strip()

black_strategy = None
white_strategy = None

if mode == "1":
    print("You will play as 'X'.")
    print_strategy_files(os.getcwd())
    white_strategy_file = input("Enter the AI strategy file for 'O' (e.g., white_strategy.py): ").strip()
    white_strategy = load_strategy(white_strategy_file)
elif mode == "2":
    print_strategy_files(os.getcwd())
    black_strategy_file = input("Enter the AI strategy file for 'X' (e.g., black_strategy.py): ").strip()
    white_strategy_file = input("Enter the AI strategy file for 'O' (e.g., white_strategy.py): ").strip()
    black_strategy = load_strategy(black_strategy_file)
    white_strategy = load_strategy(white_strategy_file)
else:
    print("Invalid choice. Exiting.")

game = Gomoku(black_strategy=black_strategy, white_strategy=white_strategy)
game.play()
# Out:
# Welcome to Gomoku!
# Choose game mode:
# 1. Human vs AI
# 2. AI vs AI
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 5>()
#       3 print("1. Human vs AI")
#       4 print("2. AI vs AI")
# ----> 5 mode = input("Enter 1 or 2: ").strip()
#       7 black_strategy = None
#       8 white_strategy = None
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1120, in Kernel._input_request(self, prompt, ident, parent, password)
#    1117             break
#    1118 except KeyboardInterrupt:
#    1119     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1120     raise KeyboardInterrupt("Interrupted by user") from None
#    1121 except Exception:
#    1122     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from alpha0v2_strategy_v2 import AlphaZeroNet
from alpha0v2_strategy_v2 import MCTS

# %%
# ------------------------------
# Data Generation via Self-Play
# ------------------------------
def self_play_game(model, board_size, mcts_simulations=5):
    """Generate training data via self-play"""
    # 检查是否有 GPU 并将模型移动到 GPU
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    # 初始化棋盘和 MCTS
    board = [['.' for _ in range(board_size)] for _ in range(board_size)]
    mcts = MCTS(model, board_size)
    current_player = 'X'
    last_move = None
    game_data = []  # Store (state, policy, value) for training
    winner = None

    while True:

        # Run MCTS to get the move and actions
        move, actions = mcts.run(board, current_player, mcts_simulations, last_move=last_move)

        # Step 1: 提取所有 (action, Q + u) 对
        action_values = [(action, node.get_value(c_puct=5.0)) for action, node in actions.items()]

        # Step 2: 计算所有 (Q + u) 的 softmax 概率
        values = np.array([value for _, value in action_values])
        exp_values = np.exp(values - np.max(values))  # 稳定的 softmax 计算
        probabilities = exp_values / np.sum(exp_values)

        # Step 3: 生成结果数组
        action_probs = [(action, prob) for (action, _), prob in zip(action_values, probabilities)]
        
        state = mcts.board_to_tensor(board, current_player, last_move).squeeze(0).detach().cpu().numpy()

        # Make the move
        board = mcts.make_move(board, move, current_player)

        # Store state and policy
#         state = np.zeros((4, board_size, board_size))

#         # 当前玩家的棋子位置
#         for x in range(board_size):
#             for y in range(board_size):
#                 if board[x][y] == current_player:
#                     state[0][x][y] = 1.0
#                 elif board[x][y] != '.':  # 对手的棋子位置
#                     state[1][x][y] = 1.0

#         # 最近一次落子的位置
#         if last_move is not None:
#             state[2][last_move[0]][last_move[1]] = 1.0

#         # 当前轮到谁下棋
#         if current_player == 'O':  # 如果是偶数回合，轮到白棋
#             state[3][:, :] = 1.0

        # 更新 last_move
        last_move = move

        # 转换动作概率
        action_probs_np = np.zeros((board_size, board_size))
        for (x, y), prob in action_probs:
            action_probs_np[x, y] = prob

        # 检查胜利条件
        if mcts.check_winner(board, current_player):
            winner = current_player
            game_data.append([state, action_probs_np, 1 if winner == 'X' else -1])
            break

        # 检查平局
        if not mcts.get_legal_moves(board):
            winner = None  # Draw
            game_data.append([state, action_probs_np, 0])
            break

        # 切换玩家
        current_player = 'O' if current_player == 'X' else 'X'

    return game_data

# %%
def compute_softmax_probabilities(children):
    # Step 1: 提取所有 (action, value_sum) 对
    action_values = [(action, node.value_sum) for action, node in children.items()]

    # Step 2: 计算所有 value_sum 的 softmax 概率
    values = np.array([value_sum for _, value_sum in action_values])
    exp_values = np.exp(values - np.max(values))
    probabilities = exp_values / np.sum(exp_values)

    # Step 3: 生成结果数组
    result = [(action, prob) for (action, _), prob in zip(action_values, probabilities)]
    return result

# %%
def train_alphazero(model, white_strategy, board_size, iterations=100, games_per_iteration=10, 
                    batch_size=32, mcts_simulations=100, alpha=0.5, l2_lambda=1e-4, entropy_alpha=1e-3):
    """Train AlphaZero model"""
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    # Move model to GPU if available
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.002)
    replay_buffer = deque(maxlen=10000)  # Replay buffer to store training data
    loss_fn_policy = nn.CrossEntropyLoss()
    loss_fn_value = nn.MSELoss()

    policy_loss_list = []
    value_loss_list = []
    results_list = [] 

    for iteration in range(iterations):
        # Generate self-play data
        for _ in range(games_per_iteration):
            game_data = self_play_game(model, board_size, mcts_simulations)
            replay_buffer.extend(game_data)
        
        # Sample a batch from replay buffer
        if len(replay_buffer) < batch_size:
            continue

        batch = random.sample(replay_buffer, batch_size)
        states, policies, values = zip(*batch)

        # Move data to GPU
        states = torch.tensor(np.stack(states), dtype=torch.float32).to(device)
        policies = torch.tensor(np.stack(policies), dtype=torch.float32).view(batch_size, 
                                                        board_size * board_size).to(device)
        values = torch.tensor(values, dtype=torch.float32).view(-1, 1).to(device)

        # Forward pass
        pred_policies, pred_values = model(states)

        # Compute losses
        policy_loss = loss_fn_policy(pred_policies, policies)
        value_loss = loss_fn_value(pred_values, values)

        l2_reg = sum(param.pow(2).sum() for param in model.parameters())
        #entropy = -torch.sum(pred_policies * torch.log(pred_policies + 1e-8), dim=1).mean()

        loss = (policy_loss * alpha + value_loss * (1 - alpha)
                + l2_lambda * l2_reg)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        policy_loss_list.append(policy_loss.item())
        value_loss_list.append(value_loss.item())

        print(f"Iteration {iteration + 1}/{iterations}")
        print(f"Policy Loss: {policy_loss.item():.4f}, Value Loss: {value_loss.item():.4f}")

        # Every 10 iterations, evaluate against pure MCTS
        if (iteration + 1) % 10 == 0:
            print(f"Starting evaluation against pure MCTS at iteration {iteration + 1}")
            model_copy = copy.deepcopy(model)
            wins, losses, ties = play_with_model_and_strategy(model_copy,
                                                              white_strategy, board_size=board_size, rounds=10)
            print("win: {}, lose: {}, tie:{}".format(wins, losses, ties))
            results_list.append((wins, losses, ties))

    # Save model weights
    torch.save(model.state_dict(), "alphazero_weights.pth")
    print("Training complete. Weights saved to 'alphazero_weights.pth'.")

    return policy_loss_list, value_loss_list, results_list

# %%
import torch

def play_with_model_and_strategy(alpha_zero_model, white_strategy, board_size=8, rounds=1):
    """
    使用 AlphaZero 模型和 white_strategy 策略进行对弈
    Args:
        alpha_zero_model: AlphaZero 模型实例
        white_strategy: 白棋的策略函数
        board_size: 棋盘大小
        rounds: 对弈的轮数
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    

    # 将模型移动到 GPU
    alpha_zero_model = alpha_zero_model.to(device)
    alpha_zero_model.eval()

    scores = {'AlphaZero': 0, 'WhiteStrategy': 0, 'Draw': 0}
    mcts = MCTS(alpha_zero_model,board_size)
    for _ in range(rounds):
        # 初始化棋盘和游戏状态
        board = [['.' for _ in range(board_size)] for _ in range(board_size)]
        current_player = 'X'  # AlphaZero 先手
        winner = None
        last_move = None

        while True:
            if current_player == 'X':  # AlphaZero 的回合
                board_tensor = mcts.board_to_tensor(board, current_player,last_move).to(device)
                best_action, _ = mcts.run(board,current_player)
                #print(best_action)
                x, y = best_action
                move = x,y
            else:  # white_strategy 的回合
                move = white_strategy(board, 'O')

                x, y = move

            # 执行落子
            if board[x][y] == '.':
                board[x][y] = current_player

                # 检查是否获胜
                if mcts.check_winner(board, current_player):
                    if current_player == 'X':
                        scores['AlphaZero'] += 1
                    else:
                        scores['WhiteStrategy'] += 1
                    break

                # 切换玩家
                current_player = 'O' if current_player == 'X' else 'X'
            else:
                #scores['WhiteStrategy' if current_player == 'X' else 'AlphaZero'] += 1
                break
            last_move = move

        # 检查是否平局
        if not any('.' in row for row in board) and winner is None:

            scores['Draw'] += 1

    # 打印对弈结果

    return scores['AlphaZero'],scores['WhiteStrategy'],scores['Draw']

# %%
board_size = 8
model = AlphaZeroNet(board_size)
white_strategy = load_strategy('./mcts_strategy.py')

policy_loss, value_loss, results_list = train_alphazero(
                        model=model,
                        white_strategy = white_strategy,
                        board_size=board_size,
                        iterations=160,
                        games_per_iteration=5,
                        batch_size=16,
                        mcts_simulations=20,
                        alpha=0.5,
                        l2_lambda=0)
# Out:
# Using device: cpu
# Iteration 4/160
# Policy Loss: 4.1800, Value Loss: 0.9963
# Iteration 5/160
# Policy Loss: 4.0979, Value Loss: 0.9723
# Iteration 6/160
# Policy Loss: 3.9961, Value Loss: 0.9520
# Iteration 7/160
# Policy Loss: 3.8213, Value Loss: 0.9316
# Iteration 8/160
# Policy Loss: 3.7608, Value Loss: 0.9340
# Iteration 9/160
# Policy Loss: 3.1620, Value Loss: 0.9194
# Iteration 10/160
# Policy Loss: 3.1009, Value Loss: 0.9191
# Starting evaluation against pure MCTS at iteration 10
# win: 0, lose: 10, tie:0
# Iteration 11/160
# Policy Loss: 3.9184, Value Loss: 0.7935
# Iteration 12/160
# Policy Loss: 2.1849, Value Loss: 0.5636
# Iteration 13/160
# Policy Loss: 2.3252, Value Loss: 0.3776
# Iteration 14/160
# Policy Loss: 3.8471, Value Loss: 0.2455
# Iteration 15/160
# Policy Loss: 3.1772, Value Loss: 0.2065
# Iteration 16/160
# Policy Loss: 3.0268, Value Loss: 0.5663
# Iteration 17/160
# Policy Loss: 3.2802, Value Loss: 0.8654
# Iteration 18/160
# Policy Loss: 2.9821, Value Loss: 0.2820
# Iteration 19/160
# Policy Loss: 3.0807, Value Loss: 0.3381
# Iteration 20/160
# Policy Loss: 3.1157, Value Loss: 0.0977
# Starting evaluation against pure MCTS at iteration 20
# win: 0, lose: 10, tie:0
# Iteration 21/160
# Policy Loss: 3.0688, Value Loss: 0.4189
# Iteration 22/160
# Policy Loss: 3.1205, Value Loss: 0.4136
# Iteration 23/160
# Policy Loss: 3.4933, Value Loss: 0.3307
# Iteration 24/160
# Policy Loss: 2.6799, Value Loss: 0.3302
# Iteration 25/160
# Policy Loss: 3.5957, Value Loss: 0.2474
# Iteration 26/160
# Policy Loss: 2.7902, Value Loss: 0.4935
# Iteration 27/160
# Policy Loss: 3.0435, Value Loss: 0.2463
# Iteration 28/160
# Policy Loss: 3.4615, Value Loss: 0.3270
# Iteration 29/160
# Policy Loss: 3.4534, Value Loss: 0.4889
# Iteration 30/160
# Policy Loss: 3.1043, Value Loss: 0.5675
# Starting evaluation against pure MCTS at iteration 30
# win: 0, lose: 10, tie:0
# Iteration 31/160
# Policy Loss: 3.3634, Value Loss: 0.3255
# Iteration 32/160
# Policy Loss: 3.8346, Value Loss: 0.4823
# Iteration 33/160
# Policy Loss: 3.2332, Value Loss: 0.3269
# Iteration 34/160
# Policy Loss: 3.1282, Value Loss: 0.4812
# Iteration 35/160
# Policy Loss: 3.1900, Value Loss: 0.4774
# Iteration 36/160
# Policy Loss: 3.2960, Value Loss: 0.6222
# Iteration 37/160
# Policy Loss: 3.6987, Value Loss: 0.2312
# Iteration 38/160
# Policy Loss: 3.7552, Value Loss: 0.2291
# Iteration 39/160
# Policy Loss: 3.8066, Value Loss: 0.3767
# Iteration 40/160
# Policy Loss: 3.5644, Value Loss: 0.3756
# Starting evaluation against pure MCTS at iteration 40
# win: 2, lose: 8, tie:0
# Iteration 41/160
# Policy Loss: 3.6402, Value Loss: 0.4491
# Iteration 42/160
# Policy Loss: 4.0098, Value Loss: 0.3851
# Iteration 43/160
# Policy Loss: 3.9339, Value Loss: 0.3992
# Iteration 44/160
# Policy Loss: 4.0662, Value Loss: 0.6164
# Iteration 45/160
# Policy Loss: 3.8081, Value Loss: 0.6665
# Iteration 46/160
# Policy Loss: 3.6029, Value Loss: 0.3246
# Iteration 47/160
# Policy Loss: 3.4720, Value Loss: 0.2962
# Iteration 48/160
# Policy Loss: 3.7464, Value Loss: 0.4135
# Iteration 49/160
# Policy Loss: 3.2349, Value Loss: 0.4060
# Iteration 50/160
# Policy Loss: 3.4991, Value Loss: 0.3369
# Starting evaluation against pure MCTS at iteration 50
# win: 2, lose: 8, tie:0
# Iteration 51/160
# Policy Loss: 3.6509, Value Loss: 0.3326
# Iteration 52/160
# Policy Loss: 3.5746, Value Loss: 0.3270
# Iteration 53/160
# Policy Loss: 3.2936, Value Loss: 0.2587
# Iteration 54/160
# Policy Loss: 3.7247, Value Loss: 0.1919
# Iteration 55/160
# Policy Loss: 3.2907, Value Loss: 0.2531
# Iteration 56/160
# Policy Loss: 3.2342, Value Loss: 0.2504
# Iteration 57/160
# Policy Loss: 3.7312, Value Loss: 0.4336
# Iteration 58/160
# Policy Loss: 3.5908, Value Loss: 0.3064
# Iteration 59/160
# Policy Loss: 3.3154, Value Loss: 0.1212
# Iteration 60/160
# Policy Loss: 3.5121, Value Loss: 0.2400
# Starting evaluation against pure MCTS at iteration 60
# win: 0, lose: 10, tie:0
# Iteration 61/160
# Policy Loss: 3.0026, Value Loss: 0.1188
# Iteration 62/160
# Policy Loss: 3.4053, Value Loss: 0.2352
# Iteration 63/160
# Policy Loss: 3.4355, Value Loss: 0.3494
# Iteration 64/160
# Policy Loss: 3.0531, Value Loss: 0.2305
# Iteration 65/160
# Policy Loss: 3.2154, Value Loss: 0.0570
# Iteration 66/160
# Policy Loss: 2.7326, Value Loss: 0.2260
# Iteration 67/160
# Policy Loss: 2.6105, Value Loss: 0.1119
# Iteration 68/160
# Policy Loss: 2.6317, Value Loss: 0.2218
# Iteration 69/160
# Policy Loss: 2.8368, Value Loss: 0.1648
# Iteration 70/160
# Policy Loss: 2.6230, Value Loss: 0.3265
# Starting evaluation against pure MCTS at iteration 70
# win: 1, lose: 9, tie:0
# Iteration 71/160
# Policy Loss: 2.6800, Value Loss: 0.1616
# Iteration 72/160
# Policy Loss: 2.6350, Value Loss: 0.2668
# Iteration 73/160
# Policy Loss: 2.6925, Value Loss: 0.3697
# Iteration 74/160
# Policy Loss: 2.1313, Value Loss: 0.2612
# Iteration 75/160
# Policy Loss: 2.1861, Value Loss: 0.2585
# Iteration 76/160
# Policy Loss: 1.8882, Value Loss: 0.1532
# Iteration 77/160
# Policy Loss: 2.6160, Value Loss: 0.4043
# Iteration 78/160
# Policy Loss: 2.3465, Value Loss: 0.2995
# Iteration 79/160
# Policy Loss: 2.3956, Value Loss: 0.2961
# Iteration 80/160
# Policy Loss: 2.3850, Value Loss: 0.3900
# Starting evaluation against pure MCTS at iteration 80
# win: 7, lose: 3, tie:0
# Iteration 81/160
# Policy Loss: 2.3180, Value Loss: 0.1930
# Iteration 82/160
# Policy Loss: 2.1422, Value Loss: 0.3318
# Iteration 83/160
# Policy Loss: 2.7395, Value Loss: 0.3731
# Iteration 84/160
# Policy Loss: 2.1177, Value Loss: 0.3671
# Iteration 85/160
# Policy Loss: 2.3321, Value Loss: 0.3611
# Iteration 86/160
# Policy Loss: 1.6893, Value Loss: 0.2221
# Iteration 87/160
# Policy Loss: 2.8772, Value Loss: 0.1748
# Iteration 88/160
# Policy Loss: 2.9200, Value Loss: 0.2574
# Iteration 89/160
# Policy Loss: 2.2339, Value Loss: 0.2532
# Iteration 90/160
# Policy Loss: 1.9330, Value Loss: 0.2069
# Starting evaluation against pure MCTS at iteration 90
# win: 4, lose: 6, tie:0
# Iteration 91/160
# Policy Loss: 1.5304, Value Loss: 0.2042
# Iteration 92/160
# Policy Loss: 2.0103, Value Loss: 0.3576
# Iteration 93/160
# Policy Loss: 1.6851, Value Loss: 0.2379
# Iteration 94/160
# Policy Loss: 1.3348, Value Loss: 0.1551
# Iteration 95/160
# Policy Loss: 1.7536, Value Loss: 0.4079
# Iteration 96/160
# Policy Loss: 1.9698, Value Loss: 0.1467
# Iteration 97/160
# Policy Loss: 1.6290, Value Loss: 0.2016
# Iteration 98/160
# Policy Loss: 1.4605, Value Loss: 0.2723
# Iteration 99/160
# Policy Loss: 1.7132, Value Loss: 0.0986
# Iteration 100/160
# Policy Loss: 0.9433, Value Loss: 0.1826
# Starting evaluation against pure MCTS at iteration 100
# win: 2, lose: 8, tie:0
# Iteration 101/160
# Policy Loss: 1.9108, Value Loss: 0.0850
# Iteration 102/160
# Policy Loss: 1.4976, Value Loss: 0.1406
# Iteration 103/160
# Policy Loss: 1.2650, Value Loss: 0.0941
# Iteration 104/160
# Policy Loss: 1.0918, Value Loss: 0.1113
# Iteration 105/160
# Policy Loss: 1.2116, Value Loss: 0.1038
# Iteration 106/160
# Policy Loss: 1.2004, Value Loss: 0.0541
# Iteration 107/160
# Policy Loss: 1.5832, Value Loss: 0.0215
# Iteration 108/160
# Policy Loss: 0.7540, Value Loss: 0.0083
# Iteration 109/160
# Policy Loss: 1.0447, Value Loss: 0.0128
# Iteration 110/160
# Policy Loss: 0.7551, Value Loss: 0.0221
# Starting evaluation against pure MCTS at iteration 110
# win: 8, lose: 2, tie:0
# Iteration 111/160
# Policy Loss: 0.6995, Value Loss: 0.0025
# Iteration 112/160
# Policy Loss: 0.9200, Value Loss: 0.0019
# Iteration 113/160
# Policy Loss: 1.1084, Value Loss: 0.0004
# Iteration 114/160
# Policy Loss: 2.0006, Value Loss: 0.0010
# Iteration 115/160
# Policy Loss: 1.0821, Value Loss: 0.0092
# Iteration 116/160
# Policy Loss: 1.3876, Value Loss: 0.0003
# Iteration 117/160
# Policy Loss: 1.4942, Value Loss: 0.0003
# Iteration 118/160
# Policy Loss: 0.9530, Value Loss: 0.0004
# Iteration 119/160
# Policy Loss: 1.5751, Value Loss: 0.0001
# Iteration 120/160
# Policy Loss: 0.8620, Value Loss: 0.0001
# Starting evaluation against pure MCTS at iteration 120
# win: 6, lose: 4, tie:0
# Iteration 121/160
# Policy Loss: 0.6275, Value Loss: 0.0001
# Iteration 122/160
# Policy Loss: 1.0876, Value Loss: 0.0006
# Iteration 123/160
# Policy Loss: 1.4493, Value Loss: 0.0007
# Iteration 124/160
# Policy Loss: 1.5194, Value Loss: 0.0002
# Iteration 125/160
# Policy Loss: 0.3552, Value Loss: 0.0001
# Iteration 126/160
# Policy Loss: 0.8767, Value Loss: 0.0000
# Iteration 127/160
# Policy Loss: 0.4840, Value Loss: 0.0000
# Iteration 128/160
# Policy Loss: 1.2116, Value Loss: 0.0000
# Iteration 129/160
# Policy Loss: 0.2552, Value Loss: 0.0000
# Iteration 130/160
# Policy Loss: 0.3724, Value Loss: 0.0000
# Starting evaluation against pure MCTS at iteration 130
# win: 7, lose: 3, tie:0
# Iteration 131/160
# Policy Loss: 0.2717, Value Loss: 0.0000
# Iteration 132/160
# Policy Loss: 0.8840, Value Loss: 0.0000
# Iteration 133/160
# Policy Loss: 0.6706, Value Loss: 0.0000
# Iteration 134/160
# Policy Loss: 1.0057, Value Loss: 0.0000
# Iteration 135/160
# Policy Loss: 0.3295, Value Loss: 0.0000
# Iteration 136/160
# Policy Loss: 0.6473, Value Loss: 0.0000
# Iteration 137/160
# Policy Loss: 0.3467, Value Loss: 0.0000
# Iteration 138/160
# Policy Loss: 0.5386, Value Loss: 0.0000
# Iteration 139/160
# Policy Loss: 0.0842, Value Loss: 0.0000
# Iteration 140/160
# Policy Loss: 0.1862, Value Loss: 0.0000
# Starting evaluation against pure MCTS at iteration 140
# win: 8, lose: 2, tie:0
# Iteration 141/160
# Policy Loss: 0.0795, Value Loss: 0.0000
# Iteration 142/160
# Policy Loss: 0.2080, Value Loss: 0.0001
# Iteration 143/160
# Policy Loss: 0.3297, Value Loss: 0.0002
# Iteration 144/160
# Policy Loss: 0.1071, Value Loss: 0.0002
# Iteration 145/160
# Policy Loss: 0.0868, Value Loss: 0.0001
# Iteration 146/160
# Policy Loss: 0.0904, Value Loss: 0.0000
# Iteration 147/160
# Policy Loss: 0.2151, Value Loss: 0.0000
# Iteration 148/160
# Policy Loss: 0.1195, Value Loss: 0.0000
# Iteration 149/160
# Policy Loss: 0.3197, Value Loss: 0.0000
# Iteration 150/160
# Policy Loss: 0.0338, Value Loss: 0.0000
# Starting evaluation against pure MCTS at iteration 150
# win: 9, lose: 1, tie:0
# Iteration 151/160
# Policy Loss: 0.5096, Value Loss: 0.0000
# Iteration 152/160
# Policy Loss: 0.4551, Value Loss: 0.0000
# Iteration 153/160
# Policy Loss: 0.1722, Value Loss: 0.0000
# Iteration 154/160
# Policy Loss: 0.0429, Value Loss: 0.0000
# Iteration 155/160
# Policy Loss: 0.0357, Value Loss: 0.0000
# Iteration 156/160
# Policy Loss: 0.0541, Value Loss: 0.0000
# Iteration 157/160
# Policy Loss: 0.0659, Value Loss: 0.0000
# Iteration 158/160
# Policy Loss: 0.2621, Value Loss: 0.0000
# Iteration 159/160
# Policy Loss: 0.0359, Value Loss: 0.0000
# Iteration 160/160
# Policy Loss: 0.2086, Value Loss: 0.0000
# Starting evaluation against pure MCTS at iteration 160
# win: 8, lose: 2, tie:0
# Training complete. Weights saved to 'alphazero_weights.pth'.

# %%
import matplotlib.pyplot as plt

plt.plot(policy_loss)
plt.show()

# %%
from matplotlib import pyplot as plt
plt.plot(value_loss)
plt.show()

# %%
board_size = 8
rounds = 10  # 对弈的轮数
weights_path = "./weights_v2/size8_win5_v2"  # AlphaZero 模型权重文件路径
#weights_path = "./weights_v2/size8_win5"  # AlphaZero 模型权重文件路径

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# 定义 white_strategy，使用简单的随机策略
white_strategy = load_strategy('./mctsv4_strategy.py')


model = AlphaZeroNet(board_size)

# 获取模型的 state_dict
state_dict = model.state_dict()

# 将权重从 list 转换为 PyTorch 张量并加载到模型
for (name, param), weight in zip(state_dict.items(), policy_param):
    print(f"Loading {name} with shape {weight.shape}")
    if "weight" in name and param.shape != torch.tensor(weight).shape:
        weight = weight.T  # 转置权重
    state_dict[name] = torch.tensor(weight, dtype=param.dtype)

# 加载更新后的 state_dict 到模型
model.load_state_dict(state_dict)

print("Model weights loaded successfully!")


model = model.to(device)
model.eval()

# 开始对弈
print(f"Starting {rounds} rounds of matches...")
alpha_zero_wins, white_strategy_wins, draws = play_with_model_and_strategy(
    alpha_zero_model,
    white_strategy,
    board_size=board_size,
    rounds=rounds,
)

print("win: {}, lose: {}, tie:{}".format(alpha_zero_wins, white_strategy_wins, draws))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 17>()
#      14 state_dict = model.state_dict()
#      16 # 将权重从 list 转换为 PyTorch 张量并加载到模型
# ---> 17 for (name, param), weight in zip(state_dict.items(), policy_param):
#      18     print(f"Loading {name} with shape {weight.shape}")
#      19     if "weight" in name and param.shape != torch.tensor(weight).shape:
#
# NameError: name 'policy_param' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d

# Read the data
file_path = 'training_log_parsed.csv'  # Update this with the path to your file
data = pd.read_csv(file_path)

# Extract columns
iterations = data['Iteration']
policy_loss = data['Policy Loss']
value_loss = data['Value Loss']

# Smooth the data using a Gaussian filter
smoothed_policy_loss = gaussian_filter1d(policy_loss, sigma=2)
smoothed_value_loss = gaussian_filter1d(value_loss, sigma=2)

# Plot Policy Loss
plt.figure(figsize=(12, 6))
plt.plot(iterations, smoothed_policy_loss, label='Smoothed Policy Loss', color='blue', linewidth=2)
plt.scatter(iterations, policy_loss, label='Raw Policy Loss', color='lightblue', s=10, alpha=0.5)
plt.title('Policy Loss over Iterations', fontsize=16)
plt.xlabel('Iterations', fontsize=14)
plt.ylabel('Policy Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(alpha=0.5)
plt.tight_layout()
plt.show()

# Plot Value Loss
plt.figure(figsize=(12, 6))
plt.plot(iterations, smoothed_value_loss, label='Smoothed Value Loss', color='green', linewidth=2)
plt.scatter(iterations, value_loss, label='Raw Value Loss', color='lightgreen', s=10, alpha=0.5)
plt.title('Value Loss over Iterations', fontsize=16)
plt.xlabel('Iterations', fontsize=14)
plt.ylabel('Value Loss', fontsize=14)
plt.legend(fontsize=12)

# %%
import matplotlib.pyplot as plt



# 计算胜率
win_rates = []
for w, l, d in results_list:
    total = w + l + d
    win_rate = w / total if total > 0 else 0
    win_rates.append(win_rate)

# 生成横轴数据，每个点的 epoch = index * 10
epochs = [i * 10 for i in range(len(win_rates))]

plt.figure(figsize=(8, 4))
plt.plot(epochs, win_rates, marker='o', linestyle='-', color='b')
plt.title("Win Rate over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Win Rate")
plt.grid(True)
plt.ylim(0, 1)
plt.show()
